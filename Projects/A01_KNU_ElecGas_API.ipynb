# %% [markdown]
# ### 경북대학교 전기가스 사용량 API 조회

# %%
import requests
import json

url = 'http://apis.data.go.kr/1611000/BldEngyService/getBeElctyUsgInfo?sigunguCd=11680&bjdongCd=10300&bun=0012&ji=0000&useYm=201501&ServiceKey=HcemfTODn25HOfvMHgFXSX%2BwwiGPX7McdKfXb09VzlvlBo3vmSQcwOx0oybt2SYSTUMa0TdDoe1nIOy7MeYdbg%3D%3D'

# <response>
# <header>
# <resultCode>00</resultCode>
# <resultMsg>NORMAL SERVICE.</resultMsg>
# </header>
# <body>
# <items>
# <item>
# <bjdongCd>10300</bjdongCd>
# <bun>0012</bun>
# <ji>0000</ji>
# <naMainBun>21.0</naMainBun>
# <naRoadCd>116804166040</naRoadCd>
# <naSubBun>0.0</naSubBun>
# <naUgrndCd>0</naUgrndCd>
# <newPlatPlc>서울특별시 강남구 개포로109길 21</newPlatPlc>
# <platGbCd>0</platGbCd>
# <platPlc>서울특별시 강남구 개포동 12번지</platPlc>
# <rnum>1</rnum>
# <sigunguCd>11680</sigunguCd>
# <useQty>1112466.0</useQty>
# <useYm>201501</useYm>
# </item>
# </items>
# <numOfRows>10</numOfRows>
# <pageNo>1</pageNo>
# <totalCount>1</totalCount>
# </body>
# </response>

# newPlatPlc = '대구광역시 북구 대학로 80' 인 데이터 조회

response = requests.get(url)
data = response.text
print(data)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><bjdongCd>10300</bjdongCd><bun>0012</bun><ji>0000</ji><naMainBun>21.0</naMainBun><naRoadCd>116804166040</naRoadCd><naSubBun>0.0</naSubBun><naUgrndCd>0</naUgrndCd><newPlatPlc>서울특별시 강남구 개포로109길 21</newPlatPlc><platGbCd>0</platGbCd><platPlc>서울특별시 강남구 개포동 12번지</platPlc><rnum>1</rnum><sigunguCd>11680</sigunguCd><useQty>1112466.0</useQty><useYm>201501</useYm></item></items><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>1</totalCount></body></response>

# %%
# 경북대학교 정보
# sigunguCd = 27230
# bjdongCd = 11100
# bun = 1370
# ji = 0001
# useYm = 202401
# numOfRows = 10
# pageNo = 1

# useYm 을 201101 ~ 202402 까지 조회
for year in range(2011, 2024):
    for month in range(1, 13):
        useYm = f'{year}{month:02d}'
        url = f'http://apis.data.go.kr/1611000/BldEngyService/getBeElctyUsgInfo?sigunguCd=27230&bjdongCd=11100&bun=1370&ji=0001&useYm={useYm}&ServiceKey=HcemfTODn25HOfvMHgFXSX%2BwwiGPX7McdKfXb09VzlvlBo3vmSQcwOx0oybt2SYSTUMa0TdDoe1nIOy7MeYdbg%3D%3D'
        response = requests.get(url)
        data = response.text
        print(data)
        break
    break
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><bjdongCd>11100</bjdongCd><bun>1370</bun><ji>0001</ji><naMainBun>80.0</naMainBun><naRoadCd>272303145021</naRoadCd><naSubBun>0.0</naSubBun><naUgrndCd>0</naUgrndCd><newPlatPlc>대구광역시 북구 대학로 80</newPlatPlc><platGbCd>0</platGbCd><platPlc>대구광역시 북구 산격동 1370-1번지</platPlc><rnum>1</rnum><sigunguCd>27230</sigunguCd><useQty>194.0</useQty><useYm>201101</useYm></item></items><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>1</totalCount></body></response>

# %%
import xml.etree.ElementTree as ET
root = ET.fromstring(data)
print(root.tag)
print(root.attrib)
for child in root:
    print(child.tag, child.attrib)
    
for item in root.iter('item'):
    print(item.tag)
    for child in item:
        print(child.tag, child.text)
# Out:
# response
# {}
# header {}
# body {}
# item
# bjdongCd 11100
# bun 1370
# ji 0001
# naMainBun 80.0
# naRoadCd 272303145021
# naSubBun 0.0
# naUgrndCd 0
# newPlatPlc 대구광역시 북구 대학로 80
# platGbCd 0
# platPlc 대구광역시 북구 산격동 1370-1번지
# rnum 1
# sigunguCd 27230
# useQty 194.0
# useYm 201101

# %%
# useQty를 출력
for item in root.iter('item'):
    for child in item:
        if child.tag == 'useQty':
            print(child.text)
# Out:
# 194.0

# %%
# 종합
import pandas as pd

df = pd.DataFrame(columns=['useYm', 'useQty'])

for year in range(2011, 2024):
    for month in range(1, 13):
        useYm = f'{year}{month:02d}'
        url = f'http://apis.data.go.kr/1611000/BldEngyService/getBeElctyUsgInfo?sigunguCd=27230&bjdongCd=11100&bun=1370&ji=0001&useYm={useYm}&ServiceKey=HcemfTODn25HOfvMHgFXSX%2BwwiGPX7McdKfXb09VzlvlBo3vmSQcwOx0oybt2SYSTUMa0TdDoe1nIOy7MeYdbg%3D%3D'
        response = requests.get(url)
        data = response.text
        root = ET.fromstring(data)
        for item in root.iter('item'):
            for child in item:
                if child.tag == 'useQty':
                    print(useYm, child.text)
                    df = df.concat(pd.DataFrame({'useYm': [useYm], 'useQty': [child.text]}))
        break

df
# Out:
# 201101 194.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 17
#      15                 if child.tag == 'useQty':
#      16                     print(useYm, child.text)
# ---> 17                     df = df.concat(pd.DataFrame({'useYm': [useYm], 'useQty': [child.text]}))
#      18         break
#      20 df
#
# File c:\Users\HOME\KDT5\KDT5_Notes\.conda\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
new_data = pd.DataFrame({'useYm': ['202201', '202202'], 'useQty': [100, 200]})
df = pd.concat([df, new_data], ignore_index=True)

# %%
import pandas as pd
import requests
import xml.etree.ElementTree as ET

df = pd.DataFrame(columns=['useYm', 'useQty'])

for year in range(2011, 2024):
    for month in range(1, 13):
        useYm = f'{year}{month:02d}'
        url = f'http://apis.data.go.kr/1611000/BldEngyService/getBeElctyUsgInfo?sigunguCd=27230&bjdongCd=11100&bun=1370&ji=0001&useYm={useYm}&ServiceKey=HcemfTODn25HOfvMHgFXSX%2BwwiGPX7McdKfXb09VzlvlBo3vmSQcwOx0oybt2SYSTUMa0TdDoe1nIOy7MeYdbg%3D%3D'
        response = requests.get(url)
        data = response.text
        root = ET.fromstring(data)
        for item in root.iter('item'):
            for child in item:
                if child.tag == 'useQty':
                    print(useYm, child.text)
                    new_row = pd.DataFrame({'useYm': [useYm], 'useQty': [child.text]})
                    df = pd.concat([df, new_row], ignore_index=True)

print(df)
# Out:
# 201101 194.0
# 201102 188.0
# 201103 267.0
# 201104 289.0
# 201105 284.0
# 201106 1003.0
# 201107 1054.0
# 201108 450.0
# 201109 448.0
    url = f'http://apis.data.go.kr/1611000/BldEngyService/getBeElctyUsgInfo?sigunguCd=27230&bjdongCd=11100&bun=1370&ji=0001&useYm={useYm}&ServiceKey=HcemfTODn25HOfvMHgFXSX%2BwwiGPX7McdKfXb09VzlvlBo3vmSQcwOx0oybt2SYSTUMa0TdDoe1nIOy7MeYdbg%3D%3D'
    response = requests.get(url)
    data = response.text
    root = ET.fromstring(data)
    for item in root.iter('item'):
        for child in item:
            if child.tag == 'useQty':
                print(useYm, child.text)
                new_row = pd.DataFrame({'useYm': [useYm], 'useQty': [child.text]})
                df = pd.concat([df, new_row], ignore_index=True)

print(df)
# Out:
# 202401 172577.0
# 202402 141258.0
#       useYm    useQty
# 0    201101     194.0
# 1    201102     188.0
# 2    201103     267.0
# 3    201104     289.0
# 4    201105     284.0
# ..      ...       ...
# 143  202310  175957.0
# 144  202311  130124.0
# 145  202312  149871.0
# 146  202401  172577.0
# 147  202402  141258.0
#
# [148 rows x 2 columns]

# %%
df.to_csv('DATA/elec_data.csv', index=False)

# %%
# 이제 가스 데이터 조회
# example url = 'http://apis.data.go.kr/1611000/BldEngyService/getBeGasUsgInfo?sigunguCd=11680&bjdongCd=10300&bun=0012&ji=0000&useYm=201501&ServiceKey=HcemfTODn25HOfvMHgFXSX%2BwwiGPX7McdKfXb09VzlvlBo3vmSQcwOx0oybt2SYSTUMa0TdDoe1nIOy7MeYdbg%3D%3D'

df = pd.DataFrame(columns=['useYm', 'useQty'])

for year in range(2011, 2025):
    if year == 2024:
        end_month = 3
    else:
        end_month = 13
    for month in range(1, end_month):
        useYm = f'{year}{month:02d}'
        url = f'http://apis.data.go.kr/1611000/BldEngyService/getBeGasUsgInfo?sigunguCd=27230&bjdongCd=11100&bun=1370&ji=0001&useYm={useYm}&ServiceKey=HcemfTODn25HOfvMHgFXSX%2BwwiGPX7McdKfXb09VzlvlBo3vmSQcwOx0oybt2SYSTUMa0TdDoe1nIOy7MeYdbg%3D%3D'
        response = requests.get(url)
        data = response.text
        root = ET.fromstring(data)
        for item in root.iter('item'):
            for child in item:
                if child.tag == 'useQty':
                    print(useYm, child.text)
                    new_row = pd.DataFrame({'useYm': [useYm], 'useQty': [child.text]})
                    df = pd.concat([df, new_row], ignore_index=True)
                    
print(df)
# Out:
# 201101 9168269.0
# 201102 7072076.0
# 201103 5656101.0
# 201104 4096409.0
# 201105 1862692.0
# 201106 1848097.0
# 201107 2767573.0
# 201108 2996325.0
# 201109 2598040.0
# 201110 1595558.0
# 201111 2087381.0
# 201112 5869632.0
# 201201 7709910.0
# 201202 7138629.0
# 201203 5537778.0
# 201204 3784383.0
# 201205 1563247.0
# 201206 1827096.0
# 201207 2057420.0
# 201208 2900647.0
# 201209 2509299.0
# 201210 1055575.0
# 201211 2037064.0
# 201212 6120959.0
# 201301 7412747.0
# 201302 6580732.0
# 201303 4989257.0
# 201304 3458037.0
# 201305 1777585.0
# 201306 1681673.0
# 201307 2422026.0
# 201308 2985752.0
# 201309 2336134.0
